# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.chdir("C:/Users/nefi.oliver.revilla1/Desktop/Proyectos/Python/Data")

# %%
df1 = pd.read_table("2010 US School Improvement Grants.txt", sep = ",")
df1.head()
# Out:
#    Unnamed: 0                        School Name      City State  \
# 0           0  HOGARTH KINGEEKUK MEMORIAL SCHOOL  SAVOONGA    AK
# 1           1                    AKIACHAK SCHOOL  AKIACHAK    AK
# 2           2                     GAMBELL SCHOOL   GAMBELL    AK
# 3           3               BURCHELL HIGH SCHOOL   WASILLA    AK
# 4           4                       AKIAK SCHOOL     AKIAK    AK
#
#                                District Name  Model Selected  Award_Amount  \
# 0              BERING STRAIT SCHOOL DISTRICT  Transformation        471014
# 1                     YUPIIT SCHOOL DISTRICT  Transformation        520579
# 2              BERING STRAIT SCHOOL DISTRICT  Transformation        449592
# 3  MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT  Transformation        641184
# 4                     YUPIIT SCHOOL DISTRICT  Transformation        399686
#
#   Region
# 0   West
# 1   West
# 2   West
# 3   West
# 4   West

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'School Name', 'City', 'State', 'District Name',
#        'Model Selected', 'Award_Amount', 'Region'],
#       dtype='object')

# %%
df1 = df1.drop(columns = 'Unnamed: 0', axis = 1)

# %%
df1.columns
# Out:
# Index(['School Name', 'City', 'State', 'District Name', 'Model Selected',
#        'Award_Amount', 'Region'],
#       dtype='object')

# %%
fig,ax = plt.subplots()
ax.hist(df1['Award_Amount'])
plt.show()

# %%
sns.distplot(df1['Award_Amount'])
plt.show()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Histograms

# %%
# Displot()
sns.distplot(df1["Award_Amount"], hist = False, rug = True, kde_kws = {'shade': True})
plt.show()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df1["Award_Amount"], kde = False, bins = 20)
plt.show()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Regression Plots

# %%
df2 = pd.read_table("Automobile Insurance Premiums.txt", sep = ",")
df2.head()
# Out:
#         State  fatal_collisions  fatal_collisions_speeding  \
# 0     Alabama              18.8                         39
# 1      Alaska              18.1                         41
# 2     Arizona              18.6                         35
# 3    Arkansas              22.4                         18
# 4  California              12.0                         35
#
#    fatal_collisions_alc  fatal_collisions_not_distracted  \
# 0                    30                               96
# 1                    25                               90
# 2                    28                               84
# 3                    26                               94
# 4                    28                               91
#
#    fatal_collisions_no_hist  premiums  insurance_losses Region
# 0                        80    784.55            145.08  South
# 1                        94   1053.48            133.93   West
# 2                        96    899.47            110.35   West
# ...

# %%
# regplot(): this function generates a scatter plot with a regression line. The data and x, y variables must be defined.
sns.regplot(x = "insurance_losses", y = "premiums", data = df2)
plt.show()

# %%
# lmplot()
sns.lmplot(x = "insurance_losses", y = "premiums", data = df2, col = "Region")
plt.show()

# %%
# lmplot()
sns.lmplot(x = "insurance_losses", y = "premiums", data = df2, hue = "Region")
plt.show()

# %% [markdown]
# # Using Seaborn Styles

# %%
# Theme examples with sns.sset_style()
# despine() : this function drops one axis from the graph: sns.despine(left = True)
for style in ['white','dark','whitegrid','darkgrid','ticks']:
    sns.set_style(style)
    sns.distplot(df1["Award_Amount"])
    plt.show()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for style in ['white','dark','whitegrid','darkgrid','ticks']:
    sns.set_style(style)
    sns.lmplot(x = "insurance_losses", y = "premiums", data = df2, hue = "Region")
    plt.show()

# %%
df3 = pd.read_table("UsHousingDataset.txt", sep = ",")
df3.head()
# Out:
#     fips2010  fmr_0  fmr_1  fmr_2  fmr_3  fmr_4  state        metro_code  \
# 0  100199999    588    691    829   1055   1451      1  METRO33860M33860
# 1  100399999    729    762    879   1280   1471      1  METRO19300M19300
# 2  100599999    491    494    657    824    929      1  NCNTY01005N01005
# 3  100799999    692    768    882   1176   1315      1  METRO13820M13820
# 4  100999999    692    768    882   1176   1315      1  METRO13820M13820
#
#                                    areaname  county  cousub      countyname  \
# 0                        Montgomery, AL MSA       1   99999  Autauga County
# 1             Daphne-Fairhope-Foley, AL MSA       3   99999  Baldwin County
# 2                        Barbour County, AL       5   99999  Barbour County
# 3  Birmingham-Hoover, AL HUD Metro FMR Area       7   99999     Bibb County
# 4  Birmingham-Hoover, AL HUD Metro FMR Area       9   99999   Blount County
#
# ...

# %%
# Plot the pandas histogram
df3['fmr_2'].plot.hist()
plt.show()
plt.clf()

# Set the default seaborn style
sns.set()

# Plot the pandas histogram again
df3['fmr_2'].plot.hist()
plt.show()
plt.clf()

# %%
# Set the style to white
sns.set_style('white')
# Create a regression plot
sns.lmplot(data=df3,
           x='pop2010',
           y='fmr_2')
# Remove the spines
sns.despine(right = True)
# Show the plot and clear the figure
plt.show()
plt.clf()

# %% [markdown]
# # Colors in Seaborn

# %%
# Defining a color for a plot
sns.set(color_codes = True)
sns.distplot(df1['Award_Amount'], color = 'g')
plt.show()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for p in sns.palettes.SEABORN_PALETTES:
    sns.set_palette(p)
    sns.distplot(df1["Award_Amount"])
    plt.show()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Displaying Palettes
# sns.palplot(): this function displays a palette
# sns.color_palette(): returns the current palette
for p in sns.palettes.SEABORN_PALETTES:
    sns.set_palette(p)
    sns.palplot(sns.color_palette())
    plt.show()

# %%
# Set style, enable color code, and create a magenta distplot
sns.set(color_codes= True)
sns.distplot(df3['fmr_3'], color='m')
# Show the plot
plt.show()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Loop through differences between bright and colorblind palettes
for p in ['bright', 'colorblind']:
    sns.set_palette(p)
    sns.distplot(df3['fmr_3'])
    plt.show()
    # Clear the plots    
    plt.clf()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Sequential Palette
sns.palplot(sns.color_palette("Purples", n_colors = 12))
plt.show()

# %%
# General Palette
sns.palplot(sns.color_palette(palette = 'husl', n_colors = 10))
plt.show()

# %%
# Diverging Palette
sns.palplot(sns.color_palette(palette = "coolwarm", n_colors = 6))
plt.show()

# %% [markdown]
# #  Customizing with Matplotlib

# %%
fig,ax = plt.subplots()
sns.distplot(df1['Award_Amount'], ax = ax)
ax.set(xlabel = "Award_Amount")
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Award_Amount')]

# %%
fig,ax = plt.subplots()
sns.distplot(df1['Award_Amount'], ax = ax)
ax.set(xlabel = "Award_Amount",
       ylabel = "Density",
       title = "Award Amount")
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Award_Amount'),
#  Text(0, 0.5, 'Density'),
#  Text(0.5, 1.0, 'Award Amount')]

# %%
# Create a figure and axes
fig, ax = plt.subplots()
# Plot the distribution of data
sns.distplot(df3['fmr_3'], ax=ax)
# Create a more descriptive x axis label
ax.set(xlabel ="3 Bedroom Fair Market Rent")
# Show the plot
plt.show()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Create a figure and axes
fig, ax = plt.subplots()

# Plot the distribution of 1 bedroom rents
sns.distplot(df3['fmr_1'], ax=ax)

# Modify the properties of the plot
ax.set(xlabel="1 Bedroom Fair Market Rent",
       xlim=(100,1500),
       title="US Rent")

# Display the plot
plt.show()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Create a figure and axes. Then plot the data
fig, ax = plt.subplots()
sns.distplot(df3['fmr_1'], ax=ax)
# Customize the labels and limits
ax.set(xlabel="1 Bedroom Fair Market Rent", xlim=(100,1500), title="US Rent")
# Add vertical lines for the median and mean
ax.axvline(x=df3['fmr_1'].median(), color='m', label='Median', linestyle='--', linewidth=2)
ax.axvline(x=df3['fmr_1'].mean(), color='b', label='Mean', linestyle='-', linewidth=2)
# Show the legend and plot the data
ax.legend()
plt.show()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Create a plot with 1 row and 2 columns that share the y axis label
fig, (ax0, ax1) = plt.subplots(nrows= 1, ncols=2, sharey= True)

# Plot the distribution of 1 bedroom apartments on ax0
sns.distplot(df3['fmr_1'], ax= ax0)
ax0.set(xlabel="1 Bedroom Fair Market Rent", xlim=(100,1500))

# Plot the distribution of 2 bedroom apartments on ax1
sns.distplot(df3['fmr_2'], ax= ax1)
ax1.set(xlabel="2 Bedroom Fair Market Rent", xlim=(100,1500))

# Display the plot
plt.show()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Categorical Plot Types

# %%
# stripplot()
# swarmplot()
# boxplot()
# violinplot()
# lvplot()
# barplot()
# pointplot()
# countplot()

# %%
sns.stripplot(data = df,
              y = "DRG Definition",
              x = "Average Covered Charges",
              jitter = True)
sns.swarmplot(data = df,
              y = "DRG Definition",
              x = "Average Covered Charges")
sns.boxplot(data = df,
            y = "DRG Definition",
            x = "Average Covered Charges")
sns.violinplot(data = df,
               y = "DRG Definition",
               x = "Average Covered Charges")
sns.lvplot(data = df,
           y = "DRG Definition",
           x = "Average Covered Charges")
sns.barplot(data = df,
            y = "DRG Definition",
            x = "Average Covered Charges",
            hue = "Region")
sns.pointplot(data = df,
              y = "DRG Definition",
              x = "Average Covered Charges",
              hue = "Region")
sns.countplot(data = df,
              y = "DRG_Code",
              hue = "Region")

# %%
# Create the stripplot
sns.stripplot(data=df1,
         x='Award_Amount',
         y='Model Selected',
         jitter= True)
plt.show()

# %%
# Create and display a swarmplot with hue set to the Region
sns.swarmplot(data=df1,
         x='Award_Amount',
         y='Model Selected',
         hue ='Region')
plt.show()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 34.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Create a boxplot
sns.boxplot(data=df1,
         x='Award_Amount',
         y='Model Selected')

plt.show()
plt.clf()

# %%
# Create a violinplot with the husl palette
sns.violinplot(data=df1,
         x='Award_Amount',
         y='Model Selected',
         palette ='husl')

plt.show()
plt.clf()

# %%
# Show a countplot with the number of models used with each region a different color
sns.countplot(data=df1,
         y="Model Selected",
         hue="Region")

plt.show()
plt.clf()

# %%
# Create a pointplot and include the capsize in order to show caps on the error bars
sns.pointplot(data=df1,
         y='Award_Amount',
         x='Model Selected',
         capsize=.1)

plt.show()

# %%
# Create a barplot with each Region shown as a different color
sns.barplot(data= df1,
         y='Award_Amount',
         x='Model Selected',
         hue = "Region")

plt.show()
plt.clf()

# %% [markdown]
# # Regression Plots

# %%
df4 = pd.read_table("WashingtonDcBike.txt", sep = ",")
df4.head()
# Out:
#        dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0  2011-01-01       1   0     1        0        6           0           2
# 1  2011-01-02       1   0     1        0        0           0           2
# 2  2011-01-03       1   0     1        0        1           1           1
# 3  2011-01-04       1   0     1        0        2           1           1
# 4  2011-01-05       1   0     1        0        3           1           1
#
#        temp     atemp       hum  windspeed  casual  registered  total_rentals
# 0  0.344167  0.363625  0.805833   0.160446     331         654            985
# 1  0.363478  0.353739  0.696087   0.248539     131         670            801
# 2  0.196364  0.189405  0.437273   0.248309     120        1229           1349
# 3  0.200000  0.212122  0.590435   0.160296     108        1454           1562
# 4  0.226957  0.229270  0.436957   0.186900      82        1518           1600

# %%
# regplot()
# residplot()

# %%
sns.regplot(data = df4, x = 'temp', y = 'total_rentals', marker = '+')
plt.show()

# %%
# A residual plot is useful for evaluating the fit of the model
sns.residplot(data = df4,
              x = 'temp',
              y = 'total_rentals')
plt.show()

# %%
# Seaborn supports polynomial regression using the order parameter
sns.regplot(data = df4,
            x = 'temp',
            y = 'total_rentals',
            order = 2)
plt.show()

# %%
sns.residplot(data = df4,
              x = 'temp',
              y = 'total_rentals',
              order = 2)
plt.show()

# %%
#Categorical Values
sns.regplot(data = df4,
            x = 'mnth',
            y = 'total_rentals',
            x_jitter = .1,
            order = 2)
plt.show()

# %%
sns.regplot(data = df4,
            x = 'mnth',
            y = 'total_rentals',
            x_estimator = np.mean,
            order = 2)
plt.show()

# %%
# x_bins can be used to divide the data into discrete bins
sns.regplot(data = df4,
            x = 'temp',
            y = 'total_rentals',
            x_bins = 4)
plt.show()

# %%
df5 = pd.read_table("2018 College Scorecard Tuition.txt", sep = ',')
df5.head()
# Out:
#                                 INSTNM    OPEID  REGION  SAT_AVG_ALL  PCTPELL  \
# 0             Alabama A & M University   100200       5        850.0   0.7249
# 1  University of Alabama at Birmingham   105200       5       1147.0   0.3505
# 2                   Amridge University  2503400       5          NaN   0.7455
# 3  University of Alabama in Huntsville   105500       5       1221.0   0.3179
# 4             Alabama State University   100500       5        844.0   0.7567
#
#    PCTFLOAN  ADM_RATE_ALL       UG  AVGFACSAL COMPL_RPY_5YR_RT  ... CONTROL  \
# 0    0.8159      0.653841   4380.0     7017.0      0.477631579  ...       1
# 1    0.5218      0.604275  10331.0    10221.0      0.673230442  ...       1
# 2    0.8781           NaN     98.0     3217.0      0.636363636  ...       2
# 3    0.4589      0.811971   5220.0     9514.0      0.762222222  ...       1
# 4    0.7692      0.463858   4348.0     7940.0       0.43006993  ...       1
#
# ...

# %%
# Display a regression plot for Tuition
sns.regplot(data=df5,
         y='Tuition',
         x="SAT_AVG_ALL",
         marker='^',
         color='g')

plt.show()
plt.clf()

# %%
# Display the residual plot
sns.residplot(data=df5,
          y='Tuition',
          x="SAT_AVG_ALL",
          color='g')

plt.show()
plt.clf()

# %%
# The final plot should include a line using a 2nd order polynomial
sns.regplot(data=df5,
            y='Tuition',
            x="PCTPELL",
            x_bins=5,
            order =2)

plt.show()
plt.clf()

# %%
# Create a scatter plot by disabling the regression line
sns.regplot(data=df5,
            y='Tuition',
            x="UG",
            fit_reg= False)

plt.show()
plt.clf()

# %%
# Create a regplot and bin the data into 8 bins
sns.regplot(data=df5,
         y='Tuition',
         x="UG",
         x_bins=8)

plt.show()
plt.clf()

# %% [markdown]
# # Matrix Plots

# %%
# heatmap(): requires data to be in a grid format
# pd.crosstab()

# %%
pd.crosstab(df4['mnth'], df4['weekday'],
           values = df4['total_rentals'], aggfunc = 'mean').round(0)
# Out:
# weekday       0       1       2       3       4       5       6
# mnth
# 1        1816.0  1927.0  2568.0  2139.0  2513.0  2446.0  1957.0
# 2        2248.0  2604.0  2824.0  2813.0  2878.0  2933.0  2266.0
# 3        3301.0  3546.0  3574.0  3670.0  3817.0  3926.0  3939.0
# 4        4417.0  4516.0  4556.0  4331.0  4764.0  4387.0  4446.0
# 5        5320.0  4512.0  5025.0  5119.0  5893.0  5751.0  5978.0
# 6        5940.0  5478.0  5681.0  5701.0  5622.0  5616.0  6344.0
# 7        5298.0  5792.0  5844.0  5814.0  5624.0  5406.0  5232.0
# 8        4703.0  5518.0  5930.0  6077.0  6038.0  5958.0  5224.0
# 9        6160.0  5637.0  5184.0  5668.0  5486.0  5747.0  6394.0
# 10       4735.0  4632.0  5065.0  5505.0  5537.0  5623.0  5445.0
# 11       4126.0  4658.0  4040.0  4136.0  3994.0  4524.0  4288.0
# 12       2740.0  3498.0  3713.0  3270.0  3711.0  3742.0  3195.0

# %%
sns.heatmap(pd.crosstab(df4['mnth'], df4['weekday'],
           values = df4['total_rentals'], aggfunc = 'mean'))
plt.show()

# %%
# annot: annotations in the cells
# fmt: show the results as a integer type
# cmap: shadows in the cells "d"
# cbar: show the color bar
# linewidths: line widths
df_crosstab = pd.crosstab(df4['mnth'], df4['weekday'],
           values = df4['total_rentals'], aggfunc = 'mean')
sns.heatmap(df_crosstab,
            annot = True,
            cmap = "YlGnBu",
            cbar = False,
            linewidths = 1.)
plt.show()

# %%
# Centering a heatmap
sns.heatmap(df_crosstab,
            annot = True,
            cmap = 'YlGnBu',
            cbar = True,
            center = df_crosstab.loc[9,6])
# Out:
# <AxesSubplot:xlabel='weekday', ylabel='mnth'>

# %%
plt.figure(figsize = (20,10))
sns.heatmap(df4.corr(),
            cmap = 'YlGnBu',
            annot = True,
            linewidth = 1.0,
            vmin = -1,
            center = 0,
            vmax = 1,
            square = True
           )
plt.show()

# %%
df6 = pd.read_table("Daily Show Guests.txt", sep = ',')
df6.head()
# Out:
#    YEAR GoogleKnowlege_Occupation     Show   Group    Raw_Guest_List
# 0  1999                     actor  1/11/99  Acting    Michael J. Fox
# 1  1999                  Comedian  1/12/99  Comedy   Sandra Bernhard
# 2  1999        television actress  1/13/99  Acting     Tracey Ullman
# 3  1999              film actress  1/14/99  Acting  Gillian Anderson
# 4  1999                     actor  1/18/99  Acting  David Alan Grier

# %%
# Create a crosstab table of the data
pd_crosstab = pd.crosstab(df6["Group"], df6["YEAR"])
print(pd_crosstab)
# Plot a heatmap of the table
sns.heatmap(pd_crosstab)
# Rotate tick marks for visibility
plt.yticks(rotation=0)
plt.xticks(rotation=90)

plt.show()
# Out:
# YEAR            1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  \
# Group
# Academic           0     0     2     0     4     1    12     9    13     5
# Acting           108   100    92    84    74    51    44    44    25    26
# Advocacy           0     1     0     1     0     4     0     0     2     3
# Athletics          0     3     1     2     0     2     2     5     4     1
# Business           0     1     0     0     0     2     1     1     2     1
# Clergy             0     0     0     1     1     1     0     0     1     0
# Comedy            25    12    11     5    12     7     5     8     9     7
# Consultant         0     0     0     0     1     4     1     4     2     3
# Government         0     0     2     1     2     3     1     3     1     0
# Media             11    21    31    42    41    45    54    47    47    77
# Military           0     0     0     0     0     0     1     1     3     1
# ...

# %%
# Create the crosstab DataFrame
pd_crosstab = pd.crosstab(df6["Group"], df6["YEAR"])

# Plot a heatmap of the table with no color bar and using the BuGn palette
sns.heatmap(pd_crosstab, cbar= False, cmap="BuGn", linewidths=.3)

# Rotate tick marks for visibility
plt.yticks(rotation=0)
plt.xticks(rotation=90)

#Show the plot
plt.show()
plt.clf()

# %% [markdown]
# # Using FacetGrid, factorplot and Implot

# %%
# FacetGrid()
g = sns.FacetGrid(df5, col = 'HIGHDEG')
g.map(sns.boxplot, 'Tuition',
      order = ['1','2','3','4','5'])

# %%
# factorplot(): use for categorical data
sns.factorplot(x = "Tuition",
               data = df5,
               col = "HIGHDEG",
               kind = 'box')
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# FacetGrid(): also be used for scatter or regression plots
g = sns.FacetGrid(df5, col = 'HIGHDEG')
g.map(plt.scatter, 'Tuition','SAT_AVG_ALL')

# %%
#lmplot: plots scatter and regression plots
sns.lmplot(data = df5,
           x = 'Tuition',
           y = "SAT_AVG_ALL",
           col = 'HIGHDEG',
           fit_reg = True)

# %%
# Create FacetGrid with Degree_Type and specify the order of the rows using row_order
g2 = sns.FacetGrid(df5, 
             row ="Degree_Type",
             row_order=['Graduate', 'Bachelors', 'Associates', 'Certificate'])
# Map a pointplot of SAT_AVG_ALL onto the grid
g2.map(sns.pointplot, 'SAT_AVG_ALL')
# Show the plot
plt.show()
plt.clf()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# Create a factor plot that contains boxplots of Tuition values
sns.factorplot(data=df5,
         x='Tuition',
         kind= 'box',
         row='Degree_Type')

plt.show()
plt.clf()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# Create a facetted pointplot of Average SAT_AVG_ALL scores facetted by Degree Type 
sns.factorplot(data=df5,
        x='SAT_AVG_ALL',
        kind='point',
        row='Degree_Type',
        row_order= ['Graduate', 'Bachelors', 'Associates', 'Certificate'])

plt.show()
plt.clf()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# Create a FacetGrid varying by column and columns ordered with the degree_order variable
g = sns.FacetGrid(df5, col ="Degree_Type")

# Map a scatter plot of Undergrad Population compared to PCTPELL
g.map(plt.scatter, 'UG', 'PCTPELL')

plt.show()
plt.clf()

# %%
# Re-create the plot above as an lmplot
sns.lmplot(data=df5,
        x ='UG',
        y ='PCTPELL',
        col="Degree_Type",
          )

plt.show()
plt.clf()

# %%
# Create an lmplot that has a column for Ownership, a row for Degree_Type and hue based on the WOMENONLY column
sns.lmplot(data=df5,
        x='SAT_AVG_ALL',
        y='Tuition',
        col ="Ownership",
        row ='Degree_Type',
        row_order=['Graduate', 'Bachelors'],
        hue ='WOMENONLY',
          )

plt.show()
plt.clf()

# %% [markdown]
# # Using PairGrid and pairplot

# %%
df2.head()
# Out:
#         State  fatal_collisions  fatal_collisions_speeding  \
# 0     Alabama              18.8                         39
# 1      Alaska              18.1                         41
# 2     Arizona              18.6                         35
# 3    Arkansas              22.4                         18
# 4  California              12.0                         35
#
#    fatal_collisions_alc  fatal_collisions_not_distracted  \
# 0                    30                               96
# 1                    25                               90
# 2                    28                               84
# 3                    26                               94
# 4                    28                               91
#
#    fatal_collisions_no_hist  premiums  insurance_losses Region
# 0                        80    784.55            145.08  South
# 1                        94   1053.48            133.93   West
# 2                        96    899.47            110.35   West
# ...

# %%
# PairGrid()
# Create a PairGrid with a scatter plot for fatal_collisions and premiums
g = sns.PairGrid(df2, vars=["fatal_collisions", "premiums"])
g2 = g.map(plt.scatter)

plt.show()
plt.clf()

# %%
g = sns.PairGrid(df, vars = ["Fair_Mrkt_Rent", "Median_Income"])
g = g.map_diag(plt.hist) # mean diagonal
g = g.map_offdiag(plt.scatter) # altern diagonal

# %%
# Create the same PairGrid but map a histogram on the diag
g = sns.PairGrid(df2, vars=["fatal_collisions", "premiums"])
g2 = g.map_diag(plt.hist)
g3 = g2.map_offdiag(plt.scatter)

plt.show()
plt.clf()

# %%
sns.pairplot(df,
             vars = ["Fair_Mrkt_Rent", "Median Income"],
             kind = "reg", # mean diagonal
             diag_kind = 'hist' ) #altern diagonal

# %%
# Create a pairwise plot of the variables using a scatter plot
sns.pairplot(data=df2,
        vars=["fatal_collisions", "premiums"],
        kind='scatter')

plt.show()
plt.clf()

# %%
sns.pairplot(df.query('CONDICION'),
             vars = ["",""],
             hue = "",
             palette = "husl",
             plot_kws = {'alpha': 0.5})

# %%
# Plot the same data but use a different color palette and color code by Region
sns.pairplot(data=df2,
        vars=["fatal_collisions", "premiums"],
        kind='scatter',
        diag_kind = 'hist',     
        hue ='Region',
        palette='RdBu',
        diag_kws={'alpha':.5})

plt.show()
plt.clf()

# %%
# Build a pairplot with different x and y variables
sns.pairplot(data=df2,
        x_vars =["fatal_collisions_speeding", "fatal_collisions_alc"],
        y_vars =['premiums', 'insurance_losses'],
        kind='scatter',
        hue='Region',
        palette='husl')

plt.show()
plt.clf()

# %%
# plot relationships between insurance_losses and premiums
sns.pairplot(data=df2,
             vars=["insurance_losses", "premiums"],
             kind ='reg',
             palette='BrBG',
             diag_kind = 'kde',
             hue='Region')

plt.show()
plt.clf()

# %% [markdown]
# # Using JointGrid and jointplot

# %%
g = sns.JointGrid(data = df5,
                  x = "Tuition",
                  y = "ADM_RATE_ALL")
g.plot(sns.regplot, sns.distplot)
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Build a JointGrid comparing humidity and total_rentals
sns.set_style("whitegrid")
g = sns.JointGrid( x= "hum",
            y ="total_rentals",
            data=df4,
            xlim=(0.1, 1.0)) 

g.plot(sns.regplot, sns.distplot)

plt.show()
plt.clf()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Build a JointGrid comparing humidity and total_rentals
sns.set_style("whitegrid")
g = sns.JointGrid( x= "hum",
            y ="total_rentals",
            data=df4,
            xlim=(0.1, 1.0)) 

g.plot(sns.regplot, sns.distplot)

plt.show()
plt.clf()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
from scipy import stats
g = sns.JointGrid(data = df5,
                  x = "Tuition",
                  y = "ADM_RATE_ALL")
g = g.plot_joint(sns.kdeplot)
g = g.plot_marginals(sns.kdeplot, shade = True)
#g = g.annotate(stats.pearsonr)

# %%
#jointplot()
g = (sns.jointplot(x = "Tuition",
              y = "ADM_RATE_ALL",
              kind = 'scatter',
              xlim = (0,25000),
              marginal_kws = dict(bins = 15,
                                  rug = True),
              data = df5.query('UG < 2500 & Ownership == "Public"'))
    .plot_joint(sns.kdeplot))
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\axisgrid.py:2203: UserWarning: The marginal plotting function has changed to `histplot`, which does not accept the following argument(s): rug.
#   warnings.warn(msg, UserWarning)

# %%
# Plot temp vs. total_rentals as a regression plot
sns.jointplot(x="temp",
         y="total_rentals",
         kind='reg',
         data=df4,
         order= 2,
         xlim=(0, 1))

plt.show()
plt.clf()

# %%
# Plot a jointplot showing the residuals
sns.jointplot(x="temp",
        y="total_rentals",
        kind='resid',
        data=df4,
        order=2)

plt.show()
plt.clf()

# %%
# Create a jointplot of temp vs. casual riders
# Include a kdeplot over the scatter plot
g = (sns.jointplot(x="temp",
             y="casual",
             kind='scatter',
             data=df4,
             marginal_kws=dict(bins=10, rug=True))
    .plot_joint(sns.kdeplot))
    
plt.show()
plt.clf()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\axisgrid.py:2203: UserWarning: The marginal plotting function has changed to `histplot`, which does not accept the following argument(s): rug.
#   warnings.warn(msg, UserWarning)

# %%
# Replicate the above plot but only for registered riders
g = (sns.jointplot(x="temp",
             y="registered",
             kind='scatter',
             data=df4,
             marginal_kws=dict(bins=10, rug=True))
    .plot_joint(sns.kdeplot))

plt.show()
plt.clf()
# Out:
# C:\Users\nefi.oliver.revilla1\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\axisgrid.py:2203: UserWarning: The marginal plotting function has changed to `histplot`, which does not accept the following argument(s): rug.
#   warnings.warn(msg, UserWarning)
